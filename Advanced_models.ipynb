# %% [markdown]
# <a href="https://colab.research.google.com/github/wujinja-cgu/Autoencoder/blob/main/Advanced_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tansformer Models:**
# Transformers are a class of deep learning models primarily used for natural language processing (NLP) tasks. They have also been applied to various other domains, such as computer vision.
# Example: Using Hugging Face's Transformers library in Python to fine-tune a pre-trained transformer model for sentiment analysis:

# %%
# !pip install transformers
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

input_text = "This is a great product!"
inputs = tokenizer(input_text, return_tensors="pt", padding=True, truncation=True)
outputs = model(**inputs)
predictions = torch.softmax(outputs.logits, dim=1)
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 47.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 87.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # **Multimodality:**
# Multimodal models are designed to handle data from multiple sources or modalities, such as text, images, and audio. These models can learn to make predictions using information from various inputs.
# Example: Using PyTorch to create a simple multimodal model that takes text and image inputs and predicts whether they are related:

# %%
import torch
import torch.nn as nn

class MultimodalModel(nn.Module):
    def __init__(self, text_input_dim, image_input_dim, output_dim):
        super(MultimodalModel, self).__init()
        self.text_encoder = nn.Linear(text_input_dim, 128)
        self.image_encoder = nn.Linear(image_input_dim, 128)
        self.fc = nn.Linear(256, output_dim)

    def forward(self, text_input, image_input):
        text_encoded = self.text_encoder(text_input)
        image_encoded = self.image_encoder(image_input)
        concatenated = torch.cat((text_encoded, image_encoded), dim=1)
        output = self.fc(concatenated)
        return output

# %% [markdown]
# # **Transfer Learning:**
# Transfer learning involves using pre-trained models as a starting point for new tasks. This can save training time and data requirements.
# Example: Using TensorFlow and the Keras API to perform transfer learning with a pre-trained image classification model (e.g., InceptionV3) on a new dataset:

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator

base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(150, 150, 3))
for layer in base_model.layers:
    layer.trainable = False

# Add custom classification layers
model = tf.keras.models.Sequential([
    base_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Load and preprocess your dataset
# Train the model with your data
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %% [markdown]
# # **Federated Learning:**
# Federated learning is a decentralized approach to machine learning where models are trained across multiple devices or servers while keeping data local.
# Example: Using PySyft, a library for federated learning in Python, to perform federated learning on remote devices:

# %%
# !pip install syft
import syft as sy

# Create a PySyft hook for decentralized computing
hook = sy.TorchHook(torch)

# Define remote workers (simulated devices)
bob = sy.VirtualWorker(hook, id="bob")
alice = sy.VirtualWorker(hook, id="alice")

# Define a model
model = ...

# Send the model to the remote workers
model.send(bob)
model.send(alice)

# Perform federated learning, e.g., by aggregating updates from workers
# Out:
# Collecting syft
#   Downloading syft-0.8.1-py2.py3-none-any.whl (338 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.8/338.8 kB 4.0 MB/s eta 0:00:00
# Collecting bcrypt==4.0.1 (from syft)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 10.0 MB/s eta 0:00:00
# Collecting forbiddenfruit==0.1.4 (from syft)
#   Downloading forbiddenfruit-0.1.4.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gevent==22.10.2 (from syft)
#   Downloading gevent-22.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 18.2 MB/s eta 0:00:00
# Collecting gipc==1.5.0 (from syft)
#   Downloading gipc-1.5.0.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jax==0.4.10 (from syft)
#   Downloading jax-0.4.10.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jaxlib==0.4.10 (from syft)
#   Downloading jaxlib-0.4.10-cp310-cp310-manylinux2014_x86_64.whl (69.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 MB 9.6 MB/s eta 0:00:00
# Collecting loguru==0.7.0 (from syft)
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.6 MB/s eta 0:00:00
# Collecting networkx==2.8 (from syft)
#   Downloading networkx-2.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<=1.24.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from syft) (1.23.5)
# Collecting opendp==0.7.0 (from syft)
#   Downloading opendp-0.7.0-py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 68.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.10/dist-packages (from syft) (23.2)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.10/dist-packages (from syft) (1.5.3)
# Collecting pyarrow==11.0.0 (from syft)
#   Downloading pyarrow-11.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 14.7 MB/s eta 0:00:00
# Collecting pycapnp==1.3.0 (from syft)
#   Downloading pycapnp-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 68.9 MB/s eta 0:00:00
# Collecting pydantic[email]==1.10.7 (from syft)
#   Downloading pydantic-1.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 69.0 MB/s eta 0:00:00
# Collecting pymongo==4.3.3 (from syft)
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 32.5 MB/s eta 0:00:00
# Collecting pynacl==1.5.0 (from syft)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 42.8 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq<=25.1.0,>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from syft) (23.2.1)
# Collecting redis==4.5.5 (from syft)
#   Downloading redis-4.5.5-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from syft) (2.31.0)
# Collecting RestrictedPython==6.0 (from syft)
#   Downloading RestrictedPython-6.0-py3-none-any.whl (25 kB)
# Collecting result==0.10.0 (from syft)
#   Downloading result-0.10.0-py3-none-any.whl (8.2 kB)
# Collecting tqdm==4.65.0 (from syft)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.8 MB/s eta 0:00:00
# Collecting typeguard==2.13.3 (from syft)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting typing-extensions==4.6.3 (from syft)
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting sherlock[filelock,redis]==0.4.1 (from syft)
#   Downloading sherlock-0.4.1-py3-none-any.whl (16 kB)
# Collecting uvicorn[standard]==0.22.0 (from syft)
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00
# Collecting fastapi==0.97.0 (from syft)
#   Downloading fastapi-0.97.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.7 MB/s eta 0:00:00
# Collecting hagrid>=0.3 (from syft)
#   Downloading hagrid-0.3.78-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (from syft) (3.7.1)
# Collecting dm-haiku==0.0.9 (from syft)
#   Downloading dm_haiku-0.0.9-py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 32.4 MB/s eta 0:00:00
# Collecting itables==1.5.3 (from syft)
#   Downloading itables-1.5.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 21.5 MB/s eta 0:00:00
# Collecting transformers==4.30.2 (from syft)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 91.0 MB/s eta 0:00:00
# Collecting evaluate==0.4.0 (from syft)
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 9.5 MB/s eta 0:00:00
# Collecting torch==2.0.1 (from syft)
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from dm-haiku==0.0.9->syft) (1.4.0)
# Collecting jmp>=0.0.2 (from dm-haiku==0.0.9->syft)
#   Downloading jmp-0.0.4-py3-none-any.whl (18 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from dm-haiku==0.0.9->syft) (0.9.0)
# Collecting datasets>=2.0.0 (from evaluate==0.4.0->syft)
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 35.9 MB/s eta 0:00:00
# Collecting dill (from evaluate==0.4.0->syft)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->syft) (3.4.1)
# Collecting multiprocess (from evaluate==0.4.0->syft)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->syft) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.4.0->syft) (0.17.3)
# Collecting responses<0.19 (from evaluate==0.4.0->syft)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<2.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.97.0->syft) (1.10.13)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.97.0->syft)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.1 MB/s eta 0:00:00
# Collecting zope.event (from gevent==22.10.2->syft)
#   Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Collecting zope.interface (from gevent==22.10.2->syft)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from gevent==22.10.2->syft) (67.7.2)
# Requirement already satisfied: greenlet>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gevent==22.10.2->syft) (3.0.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from itables==1.5.3->syft) (7.34.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.10->syft) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax==0.4.10->syft) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.10->syft) (1.11.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->syft) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.5.3->syft) (2023.3.post1)
# Collecting email-validator>=1.0.3 (from pydantic[email]==1.10.7->syft)
#   Downloading email_validator-2.1.0.post1-py3-none-any.whl (32 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo==4.3.3->syft)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 26.8 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pynacl==1.5.0->syft) (1.16.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis==4.5.5->syft) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->syft) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->syft) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->syft) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->syft) (2023.7.22)
# Requirement already satisfied: filelock<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from sherlock[filelock,redis]==0.4.1->syft) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->syft) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->syft) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1->syft)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 61.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1->syft)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 52.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1->syft)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 86.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1->syft)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 727.7 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1->syft)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1->syft)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1->syft)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 11.8 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1->syft)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 9.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1->syft)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1->syft)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 4.8 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1->syft)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 10.3 MB/s eta 0:00:00
# Collecting triton==2.0.0 (from torch==2.0.1->syft)
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->syft) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->syft) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2->syft)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 96.5 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2->syft) (0.4.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]==0.22.0->syft) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]==0.22.0->syft)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]==0.22.0->syft)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 31.6 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]==0.22.0->syft)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]==0.22.0->syft)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.6 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]==0.22.0->syft)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.7 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]==0.22.0->syft)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->syft) (0.41.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->syft) (3.27.7)
# Collecting lit (from triton==2.0.0->torch==2.0.1->syft)
#   Downloading lit-17.0.3.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 16.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ascii-magic (from hagrid>=0.3->syft)
#   Downloading ascii_magic-2.3.0-py3-none-any.whl (733 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.2/733.2 kB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=41.0.4 in /usr/local/lib/python3.10/dist-packages (from hagrid>=0.3->syft) (41.0.4)
# Collecting gitpython (from hagrid>=0.3->syft)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 18.1 MB/s eta 0:00:00
# Collecting names (from hagrid>=0.3->syft)
#   Downloading names-0.3.0.tar.gz (789 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.1/789.1 kB 50.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting paramiko (from hagrid>=0.3->syft)
#   Downloading paramiko-3.3.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: pyOpenSSL>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from hagrid>=0.3->syft) (23.2.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from hagrid>=0.3->syft) (13.6.0)
# Collecting virtualenv-api (from hagrid>=0.3->syft)
#   Downloading virtualenv_api-2.1.18-py2.py3-none-any.whl (9.5 kB)
# Collecting virtualenv (from hagrid>=0.3->syft)
#   Downloading virtualenv-20.24.6-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 91.6 MB/s eta 0:00:00
# Collecting ansible (from hagrid>=0.3->syft)
#   Downloading ansible-8.5.0-py3-none-any.whl (47.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 MB 18.1 MB/s eta 0:00:00
# Collecting ansible-core (from hagrid>=0.3->syft)
#   Downloading ansible_core-2.15.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.4.1->pynacl==1.5.0->syft) (2.21)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate==0.4.0->syft) (3.8.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.1->syft) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi==0.97.0->syft) (3.7.1)
# Collecting resolvelib<1.1.0,>=0.5.3 (from ansible-core->hagrid>=0.3->syft)
#   Downloading resolvelib-1.0.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->syft) (2.1.3)
# Collecting colorama (from ascii-magic->hagrid>=0.3->syft)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython->hagrid>=0.3->syft)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
# Collecting jedi>=0.16 (from IPython->itables==1.5.3->syft)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.5 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->itables==1.5.3->syft) (4.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->hagrid>=0.3->syft) (3.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->syft) (1.3.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv->hagrid>=0.3->syft)
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv->hagrid>=0.3->syft) (3.11.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0->syft) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0->syft) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0->syft) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0->syft) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate==0.4.0->syft) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.97.0->syft) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi==0.97.0->syft) (1.1.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->hagrid>=0.3->syft)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->itables==1.5.3->syft) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->hagrid>=0.3->syft) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->itables==1.5.3->syft) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->itables==1.5.3->syft) (0.2.8)
# Building wheels for collected packages: forbiddenfruit, gipc, jax, names, lit
#   Building wheel for forbiddenfruit (setup.py) ... done
#   Created wheel for forbiddenfruit: filename=forbiddenfruit-0.1.4-py3-none-any.whl size=21790 sha256=dd84ececa2cdd44c0996b8e9c815db5e5edb3fe0e04afa450ad9e3a56c1a845c
#   Stored in directory: /root/.cache/pip/wheels/0c/f3/30/e6e3c3f32fbcda46da9c9828bb1268f43b422559ba6d9d5dde
#   Building wheel for gipc (setup.py) ... done
#   Created wheel for gipc: filename=gipc-1.5.0-py3-none-any.whl size=20125 sha256=baed513b74c4572dcbc78d0b1e72184a728c50c19451d3cf1f9345105181fe0f
#   Stored in directory: /root/.cache/pip/wheels/10/5e/c8/30aeb21999218f92bacbfb2777c3957e760f6eeac8c5d8dd05
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.10-py3-none-any.whl size=1480497 sha256=2fe51e06382e95b6b9d1c17d984a1eb5a12551e50bdb60c3556323fdcb71557d
#   Stored in directory: /root/.cache/pip/wheels/2f/04/51/ebc9c5225f0a0df1e56c231c1f4c9b7afd3e024ebb492eed99
#   Building wheel for names (setup.py) ... done
#   Created wheel for names: filename=names-0.3.0-py3-none-any.whl size=803681 sha256=edd488656d6e15f251d38448a7ba0141b2b3363490b850864eba417415c775ae
#   Stored in directory: /root/.cache/pip/wheels/fc/9a/6f/78f4282bbcaa2d8c678b73c54c0bb1b7a04009f0d7cec79fce
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-17.0.3-py3-none-any.whl size=93257 sha256=c83acf697879bf9226f434f8acc5c81b5468e010d9e5f3f780197baac1019324
#   Stored in directory: /root/.cache/pip/wheels/ac/b8/42/f6f56aba870f9f3cc895b2e0c970ececaafc7d191217fa10a4
# Successfully built forbiddenfruit gipc jax names lit
# Installing collected packages: tokenizers, resolvelib, pycapnp, names, lit, forbiddenfruit, distlib, zope.interface, zope.event, websockets, virtualenv-api, virtualenv, uvloop, typing-extensions, typeguard, tqdm, smmap, sherlock, result, RestrictedPython, redis, python-dotenv, pyarrow, opendp, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, loguru, jmp, jedi, httptools, h11, dnspython, dill, colorama, bcrypt, watchfiles, uvicorn, starlette, responses, pynacl, pymongo, pydantic, nvidia-cusolver-cu11, nvidia-cudnn-cu11, multiprocess, jaxlib, jax, gitdb, gevent, email-validator, dm-haiku, ascii-magic, transformers, paramiko, itables, gitpython, gipc, fastapi, ansible-core, datasets, ansible, hagrid, evaluate, triton, torch, syft
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 9.0.0
#     Uninstalling pyarrow-9.0.0:
#       Successfully uninstalled pyarrow-9.0.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2
#     Uninstalling networkx-3.2:
#       Successfully uninstalled networkx-3.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.16+cuda11.cudnn86
#     Uninstalling jaxlib-0.4.16+cuda11.cudnn86:
#       Successfully uninstalled jaxlib-0.4.16+cuda11.cudnn86
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.16
#     Uninstalling jax-0.4.16:
#       Successfully uninstalled jax-0.4.16
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.34.1
#     Uninstalling transformers-4.34.1:
#       Successfully uninstalled transformers-4.34.1
#   Attempting uninstall: triton
#     Found existing installation: triton 2.1.0
#     Uninstalling triton-2.1.0:
#       Successfully uninstalled triton-2.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu118
#     Uninstalling torch-2.1.0+cu118:
#       Successfully uninstalled torch-2.1.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.6.3 which is incompatible.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# Successfully installed RestrictedPython-6.0 ansible-8.5.0 ansible-core-2.15.5 ascii-magic-2.3.0 bcrypt-4.0.1 colorama-0.4.6 datasets-2.14.6 dill-0.3.7 distlib-0.3.7 dm-haiku-0.0.9 dnspython-2.4.2 email-validator-2.1.0.post1 evaluate-0.4.0 fastapi-0.97.0 forbiddenfruit-0.1.4 gevent-22.10.2 gipc-1.5.0 gitdb-4.0.11 gitpython-3.1.40 h11-0.14.0 hagrid-0.3.78 httptools-0.6.1 itables-1.5.3 jax-0.4.10 jaxlib-0.4.10 jedi-0.19.1 jmp-0.0.4 lit-17.0.3 loguru-0.7.0 multiprocess-0.70.15 names-0.3.0 networkx-2.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 opendp-0.7.0 paramiko-3.3.1 pyarrow-11.0.0 pycapnp-1.3.0 pydantic-1.10.7 pymongo-4.3.3 pynacl-1.5.0 python-dotenv-1.0.0 redis-4.5.5 resolvelib-1.0.1 responses-0.18.0 result-0.10.0 sherlock-0.4.1 smmap-5.0.1 starlette-0.27.0 syft-0.8.1 tokenizers-0.13.3 torch-2.0.1 tqdm-4.65.0 transformers-4.30.2 triton-2.0.0 typeguard-2.13.3 typing-extensions-4.6.3 uvicorn-0.22.0 uvloop-0.19.0 virtualenv-20.24.6 virtualenv-api-2.1.18 watchfiles-0.21.0 websockets-12.0 zope.event-5.0 zope.interface-6.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2983dd059c63> in <cell line: 2>()
#       1 get_ipython().system('pip install syft')
# ----> 2 import syft as sy
#       3
#       4 # Create a PySyft hook for decentralized computing
#       5 hook = sy.TorchHook(torch)
#
# /usr/local/lib/python3.10/dist-packages/syft/__init__.py in <module>
#      10 # relative
#      11 from . import gevent_patch  # noqa: F401
# ---> 12 from .client.client import connect  # noqa: F401
#      13 from .client.client import login  # noqa: F401
#      14 from .client.client import register  # noqa: F401
#
# /usr/local/lib/python3.10/dist-packages/syft/client/client.py in <module>
#      26 # relative
#      27 from .. import __version__
# ---> 28 from ..abstract_node import AbstractNode
#      29 from ..img.base64 import base64read
#      30 from ..node.credentials import SyftSigningKey
#
# /usr/local/lib/python3.10/dist-packages/syft/abstract_node.py in <module>
#       6
#       7 # relative
# ----> 8 from .serde.serializable import serializable
#       9 from .types.uid import UID
#      10
#
# /usr/local/lib/python3.10/dist-packages/syft/serde/__init__.py in <module>
#       2 from .array import NOTHING  # noqa: F401 F811
#       3 from .recursive import NOTHING  # noqa: F401 F811
# ----> 4 from .third_party import NOTHING  # noqa: F401 F811
#
# /usr/local/lib/python3.10/dist-packages/syft/serde/third_party.py in <module>
#      18 from pandas._libs.tslibs.timestamps import Timestamp
#      19 import pyarrow as pa
# ---> 20 import pyarrow.parquet as pq
#      21 import pydantic
#      22 from pymongo.collection import Collection
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/parquet/__init__.py in <module>
#      18 # flake8: noqa
#      19
# ---> 20 from .core import *
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/parquet/core.py in <module>
#     209
#     210
# --> 211 _filters_to_expression = _deprecate_api(
#     212     "_filters_to_expression", "filters_to_expression",
#     213     filters_to_expression, "10.0.0", DeprecationWarning)
#
# TypeError: _deprecate_api() takes 4 positional arguments but 5 were given
